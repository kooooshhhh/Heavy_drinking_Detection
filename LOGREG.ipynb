# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
bar1= pd.read_csv('data/all_accelerometer_data_pids_13.csv')
bar1
# Out:
#                    time     pid         x         y         z
# 0                     0  JB3156  0.000000  0.000000  0.000000
# 1                     0  CC6740  0.000000  0.000000  0.000000
# 2         1493733882409  SA0297  0.075800  0.027300 -0.010200
# 3         1493733882455  SA0297 -0.035900  0.079400  0.003700
# 4         1493733882500  SA0297 -0.242700 -0.086100 -0.016300
# ...                 ...     ...       ...       ...       ...
# 14057562  1493829248196  CC6740 -0.133956  0.124726 -0.010736
# 14057563  1493829248220  CC6740 -0.100764  0.180872  0.046449
# 14057564  1493829248245  CC6740 -0.131853  0.195934  0.181088
# 14057565  1493829248270  CC6740 -0.149704  0.194482  0.202393
# 14057566  1493829248294  CC6740 -0.107288  0.153548  0.168595
#
# [14057567 rows x 5 columns]

# %%
import datetime
 
timestamp = 1493733882.409
 
# Convert timestamp to datetime object
dt_object = datetime.datetime.fromtimestamp(timestamp)
 
print(dt_object)
# Out:
# 2017-05-02 19:34:42.409000

# %%
import datetime
bar1['Time']=bar1['time']/1000 # convert to seconds
bar1['Time'] = bar1['Time'].apply(lambda x: datetime.datetime.fromtimestamp(x))
bar1
#df['datetime_column'] = df['posix_timestamp'].apply(lambda x: datetime.fromtimestamp(x))
# Out:
#                    time     pid         x         y         z  \
# 0                     0  JB3156  0.000000  0.000000  0.000000
# 1                     0  CC6740  0.000000  0.000000  0.000000
# 2         1493733882409  SA0297  0.075800  0.027300 -0.010200
# 3         1493733882455  SA0297 -0.035900  0.079400  0.003700
# 4         1493733882500  SA0297 -0.242700 -0.086100 -0.016300
# ...                 ...     ...       ...       ...       ...
# 14057562  1493829248196  CC6740 -0.133956  0.124726 -0.010736
# 14057563  1493829248220  CC6740 -0.100764  0.180872  0.046449
# 14057564  1493829248245  CC6740 -0.131853  0.195934  0.181088
# 14057565  1493829248270  CC6740 -0.149704  0.194482  0.202393
# 14057566  1493829248294  CC6740 -0.107288  0.153548  0.168595
#
#                             Time
# 0        1970-01-01 05:30:00.000
# 1        1970-01-01 05:30:00.000
# 2        2017-05-02 19:34:42.409
# 3        2017-05-02 19:34:42.455
# 4        2017-05-02 19:34:42.500
# ...

# %%
bar1=bar1.drop(columns=['time'], axis=1)
bar1
# Out:
#              pid         x         y         z                    Time
# 0         JB3156  0.000000  0.000000  0.000000 1970-01-01 05:30:00.000
# 1         CC6740  0.000000  0.000000  0.000000 1970-01-01 05:30:00.000
# 2         SA0297  0.075800  0.027300 -0.010200 2017-05-02 19:34:42.409
# 3         SA0297 -0.035900  0.079400  0.003700 2017-05-02 19:34:42.455
# 4         SA0297 -0.242700 -0.086100 -0.016300 2017-05-02 19:34:42.500
# ...          ...       ...       ...       ...                     ...
# 14057562  CC6740 -0.133956  0.124726 -0.010736 2017-05-03 22:04:08.196
# 14057563  CC6740 -0.100764  0.180872  0.046449 2017-05-03 22:04:08.220
# 14057564  CC6740 -0.131853  0.195934  0.181088 2017-05-03 22:04:08.245
# 14057565  CC6740 -0.149704  0.194482  0.202393 2017-05-03 22:04:08.270
# 14057566  CC6740 -0.107288  0.153548  0.168595 2017-05-03 22:04:08.294
#
# [14057567 rows x 5 columns]

# %%
bar1=bar1.sort_values(by=['Time'])
bar1
# Out:
#              pid         x         y         z                    Time
# 0         JB3156  0.000000  0.000000  0.000000 1970-01-01 05:30:00.000
# 1         CC6740  0.000000  0.000000  0.000000 1970-01-01 05:30:00.000
# 2         SA0297  0.075800  0.027300 -0.010200 2017-05-02 19:34:42.409
# 3         SA0297 -0.035900  0.079400  0.003700 2017-05-02 19:34:42.455
# 4         SA0297 -0.242700 -0.086100 -0.016300 2017-05-02 19:34:42.500
# ...          ...       ...       ...       ...                     ...
# 14057562  CC6740 -0.133956  0.124726 -0.010736 2017-05-03 22:04:08.196
# 14057563  CC6740 -0.100764  0.180872  0.046449 2017-05-03 22:04:08.220
# 14057564  CC6740 -0.131853  0.195934  0.181088 2017-05-03 22:04:08.245
# 14057565  CC6740 -0.149704  0.194482  0.202393 2017-05-03 22:04:08.270
# 14057566  CC6740 -0.107288  0.153548  0.168595 2017-05-03 22:04:08.294
#
# [14057567 rows x 5 columns]

# %%
SA0297= pd.read_csv('data/clean_tac/SA0297_clean_TAC.csv')
SA0297
#SA0297['Time']=SA0297['timestamp']/1000 # convert to seconds
SA0297['Time'] = SA0297['timestamp'].apply(lambda x: datetime.datetime.fromtimestamp(x))
SA0297=SA0297.drop(columns=['timestamp'])
SA0297
# Out:
#     TAC_Reading                Time
# 0     -0.010229 2017-05-02 14:48:43
# 1     -0.002512 2017-05-02 15:19:06
# 2      0.003249 2017-05-02 15:24:23
# 3      0.005404 2017-05-02 15:29:39
# 4      0.003377 2017-05-02 15:34:55
# 5     -0.001451 2017-05-02 15:40:11
# 6     -0.005816 2017-05-02 15:45:27
# 7     -0.006248 2017-05-02 15:50:43
# 8     -0.001631 2017-05-02 15:55:59
# 9      0.005332 2017-05-02 16:01:15
# 10     0.009407 2017-05-02 16:06:31
# 11     0.006597 2017-05-02 16:11:47
# 12    -0.002201 2017-05-02 16:42:05
# 13    -0.010741 2017-05-02 17:12:22
# 14    -0.011314 2017-05-02 17:42:39
# 15    -0.000636 2017-05-02 18:12:57
# 16     0.016699 2017-05-02 18:43:22
# 17     0.030566 2017-05-02 19:13:44
# 18     0.032672 2017-05-02 19:44:08
# 19     0.023972 2017-05-02 20:14:33
# 20     0.016196 2017-05-02 20:45:00
# 21     0.025131 2017-05-02 21:15:42
# 22     0.059263 2017-05-02 21:46:23
# 23     0.111503 2017-05-02 22:16:47
# 24     0.160592 2017-05-02 22:47:29
# ...

# %%
plt.plot(SA0297['Time'],SA0297['TAC_Reading'])
plt.axhline(y=0.08, color='r') 
plt.xticks(rotation=90)

plt.show()

# %%
bar1
# Out:
#              pid         x         y         z                    Time
# 0         JB3156  0.000000  0.000000  0.000000 1970-01-01 05:30:00.000
# 1         CC6740  0.000000  0.000000  0.000000 1970-01-01 05:30:00.000
# 2         SA0297  0.075800  0.027300 -0.010200 2017-05-02 19:34:42.409
# 3         SA0297 -0.035900  0.079400  0.003700 2017-05-02 19:34:42.455
# 4         SA0297 -0.242700 -0.086100 -0.016300 2017-05-02 19:34:42.500
# ...          ...       ...       ...       ...                     ...
# 14057562  CC6740 -0.133956  0.124726 -0.010736 2017-05-03 22:04:08.196
# 14057563  CC6740 -0.100764  0.180872  0.046449 2017-05-03 22:04:08.220
# 14057564  CC6740 -0.131853  0.195934  0.181088 2017-05-03 22:04:08.245
# 14057565  CC6740 -0.149704  0.194482  0.202393 2017-05-03 22:04:08.270
# 14057566  CC6740 -0.107288  0.153548  0.168595 2017-05-03 22:04:08.294
#
# [14057567 rows x 5 columns]

# %%
# convert miliseconds to seconds

# %%
import pandas as pd

# Sample DataFrame with a datetime column containing milliseconds
data = {'time': ['2017-05-02 19:34:42.409', '2017-05-02 19:35:12.789']}
df = pd.DataFrame(data)

# Convert the 'time' column to a datetime object
df['time'] = pd.to_datetime(df['time'])

# Remove milliseconds by rounding down to the nearest second
df['time'] = df['time'].dt.floor('s')

# Print the updated DataFrame
print(df)
# Out:
#                  time
# 0 2017-05-02 19:34:42
# 1 2017-05-02 19:35:12

# %%
bar1['Time'] = bar1['Time'].dt.floor('s')
bar1
# Out:
#              pid         x         y         z                Time
# 0         JB3156  0.000000  0.000000  0.000000 1970-01-01 05:30:00
# 1         CC6740  0.000000  0.000000  0.000000 1970-01-01 05:30:00
# 2         SA0297  0.075800  0.027300 -0.010200 2017-05-02 19:34:42
# 3         SA0297 -0.035900  0.079400  0.003700 2017-05-02 19:34:42
# 4         SA0297 -0.242700 -0.086100 -0.016300 2017-05-02 19:34:42
# ...          ...       ...       ...       ...                 ...
# 14057562  CC6740 -0.133956  0.124726 -0.010736 2017-05-03 22:04:08
# 14057563  CC6740 -0.100764  0.180872  0.046449 2017-05-03 22:04:08
# 14057564  CC6740 -0.131853  0.195934  0.181088 2017-05-03 22:04:08
# 14057565  CC6740 -0.149704  0.194482  0.202393 2017-05-03 22:04:08
# 14057566  CC6740 -0.107288  0.153548  0.168595 2017-05-03 22:04:08
#
# [14057567 rows x 5 columns]

# %%
bar1.describe()
# Out:
#                   x             y             z                           Time
# count  1.405757e+07  1.405757e+07  1.405757e+07                       14057567
# mean  -9.269848e-03 -7.168398e+06  7.168398e+06  2017-05-03 07:49:40.560285952
# min   -4.333507e+01 -1.809008e+08 -4.902300e+01            1970-01-01 05:30:00
# 25%   -5.700000e-03 -4.500000e-03 -4.200000e-03            2017-05-03 01:21:47
# 50%   -2.000000e-04 -2.000000e-04  6.100000e-03            2017-05-03 08:09:19
# 75%    7.600000e-03  4.500000e-03  4.605889e-02            2017-05-03 14:18:10
# max    3.922540e+01  2.731123e+01  1.809008e+08            2017-05-03 22:04:08
# std    9.540696e-01  3.528998e+07  3.528998e+07                            NaN

# %%
bar1 = bar1.drop(bar1[bar1['Time'] == '1970-01-01 05:30:00'].index)
bar1
# Out:
#              pid         x         y         z                Time
# 2         SA0297  0.075800  0.027300 -0.010200 2017-05-02 19:34:42
# 3         SA0297 -0.035900  0.079400  0.003700 2017-05-02 19:34:42
# 4         SA0297 -0.242700 -0.086100 -0.016300 2017-05-02 19:34:42
# 5         SA0297 -0.288800  0.051400 -0.014500 2017-05-02 19:34:43
# 6         SA0297 -0.041300 -0.018400 -0.010500 2017-05-02 19:34:43
# ...          ...       ...       ...       ...                 ...
# 14057562  CC6740 -0.133956  0.124726 -0.010736 2017-05-03 22:04:08
# 14057563  CC6740 -0.100764  0.180872  0.046449 2017-05-03 22:04:08
# 14057564  CC6740 -0.131853  0.195934  0.181088 2017-05-03 22:04:08
# 14057565  CC6740 -0.149704  0.194482  0.202393 2017-05-03 22:04:08
# 14057566  CC6740 -0.107288  0.153548  0.168595 2017-05-03 22:04:08
#
# [14057565 rows x 5 columns]

# %%
bar1.describe()
# Out:
#                   x             y             z                           Time
# count  1.405756e+07  1.405756e+07  1.405756e+07                       14057565
# mean  -9.269850e-03 -7.168399e+06  7.168399e+06  2017-05-03 07:53:13.083289600
# min   -4.333507e+01 -1.809008e+08 -4.902300e+01            2017-05-02 19:34:42
# 25%   -5.700000e-03 -4.500000e-03 -4.200000e-03            2017-05-03 01:21:47
# 50%   -2.000000e-04 -2.000000e-04  6.100000e-03            2017-05-03 08:09:19
# 75%    7.600000e-03  4.500000e-03  4.605913e-02            2017-05-03 14:18:10
# max    3.922540e+01  2.731123e+01  1.809008e+08            2017-05-03 22:04:08
# std    9.540697e-01  3.528998e+07  3.528998e+07                            NaN

# %%
start = pd.to_datetime("2017-05-02 19:34:42")
end = pd.to_datetime("2017-05-03 22:04:08")

date_range = pd.date_range(start, end, freq='S')

data_points_formatted = [dt.strftime("%Y-%m-%d %H:%M:%S") for dt in date_range]
# Create a DataFrame with the formatted time points
df = pd.DataFrame({'Time': data_points_formatted})
# Print the DataFrame
df
# Out:
#                       Time
# 0      2017-05-02 19:34:42
# 1      2017-05-02 19:34:43
# 2      2017-05-02 19:34:44
# 3      2017-05-02 19:34:45
# 4      2017-05-02 19:34:46
# ...                    ...
# 95362  2017-05-03 22:04:04
# 95363  2017-05-03 22:04:05
# 95364  2017-05-03 22:04:06
# 95365  2017-05-03 22:04:07
# 95366  2017-05-03 22:04:08
#
# [95367 rows x 1 columns]

# %%
bar1
# Out:
#              pid         x         y         z                Time
# 2         SA0297  0.075800  0.027300 -0.010200 2017-05-02 19:34:42
# 3         SA0297 -0.035900  0.079400  0.003700 2017-05-02 19:34:42
# 4         SA0297 -0.242700 -0.086100 -0.016300 2017-05-02 19:34:42
# 5         SA0297 -0.288800  0.051400 -0.014500 2017-05-02 19:34:43
# 6         SA0297 -0.041300 -0.018400 -0.010500 2017-05-02 19:34:43
# ...          ...       ...       ...       ...                 ...
# 14057562  CC6740 -0.133956  0.124726 -0.010736 2017-05-03 22:04:08
# 14057563  CC6740 -0.100764  0.180872  0.046449 2017-05-03 22:04:08
# 14057564  CC6740 -0.131853  0.195934  0.181088 2017-05-03 22:04:08
# 14057565  CC6740 -0.149704  0.194482  0.202393 2017-05-03 22:04:08
# 14057566  CC6740 -0.107288  0.153548  0.168595 2017-05-03 22:04:08
#
# [14057565 rows x 5 columns]

# %%
bar1['Time']=bar1['Time'].dt.round('10S')
bar1
# Out:
#              pid         x         y         z                Time
# 2         SA0297  0.075800  0.027300 -0.010200 2017-05-02 19:34:40
# 3         SA0297 -0.035900  0.079400  0.003700 2017-05-02 19:34:40
# 4         SA0297 -0.242700 -0.086100 -0.016300 2017-05-02 19:34:40
# 5         SA0297 -0.288800  0.051400 -0.014500 2017-05-02 19:34:40
# 6         SA0297 -0.041300 -0.018400 -0.010500 2017-05-02 19:34:40
# ...          ...       ...       ...       ...                 ...
# 14057562  CC6740 -0.133956  0.124726 -0.010736 2017-05-03 22:04:10
# 14057563  CC6740 -0.100764  0.180872  0.046449 2017-05-03 22:04:10
# 14057564  CC6740 -0.131853  0.195934  0.181088 2017-05-03 22:04:10
# 14057565  CC6740 -0.149704  0.194482  0.202393 2017-05-03 22:04:10
# 14057566  CC6740 -0.107288  0.153548  0.168595 2017-05-03 22:04:10
#
# [14057565 rows x 5 columns]

# %%
bar1['pid'].value_counts()
# Out:
# pid
# CC6740    2374694
# PC6771    2141701
# HV0618    1876013
# DK3500    1339622
# BK7610    1225727
# JB3156    1177748
# SA0297     962901
# SF3079     662949
# MJ8002     631303
# DC6359     591358
# BU4707     447423
# MC7070     318600
# JR8022     307526
# Name: count, dtype: int64

# %%
#take mean values of each second and then continue (dataset will become smaller)
unique_bar1 = pd.DataFrame(bar1.groupby(['Time'],as_index=False)[['x','y','z']].mean())
unique_bar1
# Out:
#                     Time         x         y         z
# 0    2017-05-02 19:34:40 -0.012025 -0.002505 -0.005056
# 1    2017-05-02 19:34:50  0.000126  0.000932 -0.003042
# 2    2017-05-02 19:35:00  0.007597  0.001715 -0.000946
# 3    2017-05-02 19:35:10  0.000067  0.000155 -0.003040
# 4    2017-05-02 19:35:20 -0.000087 -0.000087 -0.001838
# ...                  ...       ...       ...       ...
# 9454 2017-05-03 22:03:30  0.025701  0.261930  0.174525
# 9455 2017-05-03 22:03:40 -0.071388  0.209505  0.230314
# 9456 2017-05-03 22:03:50  0.033098  0.301036  0.194274
# 9457 2017-05-03 22:04:00  0.107928  0.235360  0.243888
# 9458 2017-05-03 22:04:10 -0.057881  0.191652  0.172469
#
# [9459 rows x 4 columns]

# %%
# Specify start and end dates
start = '2017-05-02 19:34:40'
end = '2017-05-03 22:04:10'
# Generate dates with a frequency of 10 seconds
dataset = pd.date_range(start=start, end=end, freq='10S')

# Convert to DataFrame
df_time = pd.DataFrame(dataset, columns=['Date'])

# Print DataFrame
print(df_time)
# Out:
#                     Date
# 0    2017-05-02 19:34:40
# 1    2017-05-02 19:34:50
# 2    2017-05-02 19:35:00
# 3    2017-05-02 19:35:10
# 4    2017-05-02 19:35:20
# ...                  ...
# 9533 2017-05-03 22:03:30
# 9534 2017-05-03 22:03:40
# 9535 2017-05-03 22:03:50
# 9536 2017-05-03 22:04:00
# 9537 2017-05-03 22:04:10
#
# [9538 rows x 1 columns]

# %% [markdown]
# 2017-05-02 7:34:40 pm
# 2017-05-03 10:04:10 pm

# %% [markdown]
# 2017-05-02 5:53:40 pm
# 2017-05-03 3:50:00 pm

# %%
import glob
import pandas as pd

# Get a list of all csv files in the target directory
files = glob.glob('/Users/kush/Desktop/DATA_BACKUP_FINALLY/INSOFE_materials/PROBSANDSTATS4/End-term Project/bar+crawl+detecting+heavy+drinking/data/clean_tac/*.csv')

# Create a list of pandas dataframes
df_list = [pd.read_csv(f) for f in files]

# Concatenate all dataframes into a single dataframe
dfa = pd.concat(df_list)

# %%
dfa['Time'] = dfa['timestamp'].apply(lambda x: datetime.datetime.fromtimestamp(x))
dfa=dfa.drop(columns=['timestamp'])
dfa['Time']=dfa['Time'].dt.round('10S')
dfa
# Out:
#     TAC_Reading                Time
# 0      0.000215 2017-05-02 17:53:40
# 1      0.001716 2017-05-02 17:57:00
# 2      0.001921 2017-05-02 18:27:20
# 3      0.000569 2017-05-02 18:57:50
# 4     -0.001321 2017-05-02 19:03:10
# ..          ...                 ...
# 50     0.000115 2017-05-03 13:48:00
# 51    -0.000309 2017-05-03 14:18:30
# 52    -0.000136 2017-05-03 14:49:00
# 53     0.000097 2017-05-03 15:19:30
# 54     0.000200 2017-05-03 15:50:00
#
# [715 rows x 2 columns]

# %%
dfa=dfa.sort_values(by=['Time'])
dfa
# Out:
#     TAC_Reading                Time
# 0     -0.010229 2017-05-02 14:48:40
# 0      0.000043 2017-05-02 15:07:40
# 1     -0.002512 2017-05-02 15:19:10
# 0     -0.000482 2017-05-02 15:21:50
# 0     -0.000482 2017-05-02 15:21:50
# ..          ...                 ...
# 56    -0.002732 2017-05-03 16:08:20
# 54     0.005121 2017-05-03 16:08:40
# 57     0.001330 2017-05-03 16:33:40
# 55     0.005040 2017-05-03 16:39:10
# 58    -0.002856 2017-05-03 17:04:00
#
# [715 rows x 2 columns]

# %%
plt.plot(dfa['Time'],dfa['TAC_Reading'])

# %%
dfa.describe()
# Out:
#        TAC_Reading                           Time
# count   715.000000                            715
# mean      0.046124  2017-05-03 02:21:29.272727552
# min      -0.028308            2017-05-02 14:48:40
# 25%       0.001872            2017-05-02 19:09:35
# 50%       0.020045            2017-05-03 02:03:10
# 75%       0.076462            2017-05-03 08:56:00
# max       0.244715            2017-05-03 17:04:00
# std       0.056917                            NaN

# %%
merged_df=pd.merge(unique_bar1,dfa, on='Time', how='left')
merged_df
# Out:
#                     Time         x         y         z  TAC_Reading
# 0    2017-05-02 19:34:40 -0.012025 -0.002505 -0.005056          NaN
# 1    2017-05-02 19:34:50  0.000126  0.000932 -0.003042          NaN
# 2    2017-05-02 19:35:00  0.007597  0.001715 -0.000946          NaN
# 3    2017-05-02 19:35:10  0.000067  0.000155 -0.003040          NaN
# 4    2017-05-02 19:35:20 -0.000087 -0.000087 -0.001838          NaN
# ...                  ...       ...       ...       ...          ...
# 9504 2017-05-03 22:03:30  0.025701  0.261930  0.174525          NaN
# 9505 2017-05-03 22:03:40 -0.071388  0.209505  0.230314          NaN
# 9506 2017-05-03 22:03:50  0.033098  0.301036  0.194274          NaN
# 9507 2017-05-03 22:04:00  0.107928  0.235360  0.243888          NaN
# 9508 2017-05-03 22:04:10 -0.057881  0.191652  0.172469          NaN
#
# [9509 rows x 5 columns]

# %%
merged_df.isna().sum()
# Out:
# Time              0
# x                 0
# y                 0
# z                 0
# TAC_Reading    8988
# dtype: int64

# %%
merged_df
# Out:
#                     Time         x         y         z  TAC_Reading
# 0    2017-05-02 19:34:40 -0.012025 -0.002505 -0.005056          NaN
# 1    2017-05-02 19:34:50  0.000126  0.000932 -0.003042          NaN
# 2    2017-05-02 19:35:00  0.007597  0.001715 -0.000946          NaN
# 3    2017-05-02 19:35:10  0.000067  0.000155 -0.003040          NaN
# 4    2017-05-02 19:35:20 -0.000087 -0.000087 -0.001838          NaN
# ...                  ...       ...       ...       ...          ...
# 9504 2017-05-03 22:03:30  0.025701  0.261930  0.174525          NaN
# 9505 2017-05-03 22:03:40 -0.071388  0.209505  0.230314          NaN
# 9506 2017-05-03 22:03:50  0.033098  0.301036  0.194274          NaN
# 9507 2017-05-03 22:04:00  0.107928  0.235360  0.243888          NaN
# 9508 2017-05-03 22:04:10 -0.057881  0.191652  0.172469          NaN
#
# [9509 rows x 5 columns]

# %%
merged_df['TAC_Reading'] = merged_df['TAC_Reading'].interpolate(method='linear')
# # Set minimum and maximum limits
# min_limit = 0
# max_limit = 100

# # Apply limits to the interpolated values
# merged_df['TAC_Reading'] = df['TAC_Reading'].apply(lambda x: min(max(x, min_limit), max_limit))
# merged_df

# %%
plt.plot(merged_df['TAC_Reading'])

# %%
merged_df.isna().sum()
# Out:
# Time           0
# x              0
# y              0
# z              0
# TAC_Reading    7
# dtype: int64

# %%
merged_df.describe()
# Out:
#                                 Time            x             y             z  \
# count                           9509  9509.000000  9.509000e+03  9.509000e+03
# mean   2017-05-03 08:44:44.164475904    -0.018435 -8.044356e+06  8.044356e+06
# min              2017-05-02 19:34:40    -6.703177 -1.809008e+08 -3.937875e+00
# 25%              2017-05-03 02:10:50    -0.002342 -3.895075e-02  2.788341e-03
# 50%              2017-05-03 08:44:40     0.000949  9.120533e-04  1.226745e-01
# 75%              2017-05-03 15:18:10     0.011885  4.000710e-03  1.909992e-01
# max              2017-05-03 22:04:10     3.546317  9.377265e+00  1.809008e+08
# std                              NaN     0.448108  2.110307e+07  2.110307e+07
#
#        TAC_Reading
# count  9502.000000
# mean      0.044636
# min      -0.028308
# 25%       0.001458
# 50%       0.028263
# 75%       0.071694
# max       0.244715
# std       0.051608

# %%
merged_df= merged_df.replace(np. nan,0)
merged_df
# Out:
#                     Time         x         y         z  TAC_Reading
# 0    2017-05-02 19:34:40 -0.012025 -0.002505 -0.005056     0.000000
# 1    2017-05-02 19:34:50  0.000126  0.000932 -0.003042     0.000000
# 2    2017-05-02 19:35:00  0.007597  0.001715 -0.000946     0.000000
# 3    2017-05-02 19:35:10  0.000067  0.000155 -0.003040     0.000000
# 4    2017-05-02 19:35:20 -0.000087 -0.000087 -0.001838     0.000000
# ...                  ...       ...       ...       ...          ...
# 9504 2017-05-03 22:03:30  0.025701  0.261930  0.174525    -0.002856
# 9505 2017-05-03 22:03:40 -0.071388  0.209505  0.230314    -0.002856
# 9506 2017-05-03 22:03:50  0.033098  0.301036  0.194274    -0.002856
# 9507 2017-05-03 22:04:00  0.107928  0.235360  0.243888    -0.002856
# 9508 2017-05-03 22:04:10 -0.057881  0.191652  0.172469    -0.002856
#
# [9509 rows x 5 columns]

# %%
plt.figure(figsize=(20,5))
plt.axhline(y=0.08, color='r') 
plt.plot(merged_df['Time'],merged_df['TAC_Reading'])

# %%
merged_df['TAC_Reading'].isna().sum()
# Out:
# 0

# %%
merged_df.head(20)
# Out:
#                   Time         x         y         z  TAC_Reading
# 0  2017-05-02 19:34:40 -0.012025 -0.002505 -0.005056     0.000000
# 1  2017-05-02 19:34:50  0.000126  0.000932 -0.003042     0.000000
# 2  2017-05-02 19:35:00  0.007597  0.001715 -0.000946     0.000000
# 3  2017-05-02 19:35:10  0.000067  0.000155 -0.003040     0.000000
# 4  2017-05-02 19:35:20 -0.000087 -0.000087 -0.001838     0.000000
# 5  2017-05-02 19:35:30 -0.000181  0.000043 -0.003118     0.000000
# 6  2017-05-02 19:35:40  0.000266 -0.000014 -0.003554     0.000000
# 7  2017-05-02 19:35:50  0.000224  0.000003 -0.003221    -0.000132
# 8  2017-05-02 19:36:00 -0.000003  0.000002 -0.003022     0.000023
# 9  2017-05-02 19:36:10  0.000123 -0.000114 -0.003350     0.000178
# 10 2017-05-02 19:36:20 -0.064978  0.113126  0.025894     0.000332
# 11 2017-05-02 19:36:30 -0.000408 -0.000016 -0.003071     0.000487
# 12 2017-05-02 19:36:40 -0.000098 -0.000049 -0.003024     0.000642
# ...

# %%
merged_df = merged_df.replace(np.nan, 0)
merged_df
# Out:
#                     Time         x         y         z  TAC_Reading
# 0    2017-05-02 19:34:40 -0.012025 -0.002505 -0.005056     0.000000
# 1    2017-05-02 19:34:50  0.000126  0.000932 -0.003042     0.000000
# 2    2017-05-02 19:35:00  0.007597  0.001715 -0.000946     0.000000
# 3    2017-05-02 19:35:10  0.000067  0.000155 -0.003040     0.000000
# 4    2017-05-02 19:35:20 -0.000087 -0.000087 -0.001838     0.000000
# ...                  ...       ...       ...       ...          ...
# 9504 2017-05-03 22:03:30  0.025701  0.261930  0.174525    -0.002856
# 9505 2017-05-03 22:03:40 -0.071388  0.209505  0.230314    -0.002856
# 9506 2017-05-03 22:03:50  0.033098  0.301036  0.194274    -0.002856
# 9507 2017-05-03 22:04:00  0.107928  0.235360  0.243888    -0.002856
# 9508 2017-05-03 22:04:10 -0.057881  0.191652  0.172469    -0.002856
#
# [9509 rows x 5 columns]

# %%
plt.figure(figsize=(20,5))
plt.axhline(y=0.08, color='r') 
plt.plot(merged_df['Time'],merged_df['TAC_Reading'])

# %%
9509-(25/100)*9509
# Out:
# 7131.75

# %%
merged_df.set_index('Time', inplace=True)
merged_df
# Out:
#                             x         y         z  TAC_Reading
# Time
# 2017-05-02 19:34:40 -0.012025 -0.002505 -0.005056     0.000000
# 2017-05-02 19:34:50  0.000126  0.000932 -0.003042     0.000000
# 2017-05-02 19:35:00  0.007597  0.001715 -0.000946     0.000000
# 2017-05-02 19:35:10  0.000067  0.000155 -0.003040     0.000000
# 2017-05-02 19:35:20 -0.000087 -0.000087 -0.001838     0.000000
# ...                       ...       ...       ...          ...
# 2017-05-03 22:03:30  0.025701  0.261930  0.174525    -0.002856
# 2017-05-03 22:03:40 -0.071388  0.209505  0.230314    -0.002856
# 2017-05-03 22:03:50  0.033098  0.301036  0.194274    -0.002856
# 2017-05-03 22:04:00  0.107928  0.235360  0.243888    -0.002856
# 2017-05-03 22:04:10 -0.057881  0.191652  0.172469    -0.002856
#
# [9509 rows x 4 columns]

# %%
merged_df.describe()
# Out:
#                  x             y             z  TAC_Reading
# count  9509.000000  9.509000e+03  9.509000e+03  9509.000000
# mean     -0.018435 -8.044356e+06  8.044356e+06     0.044603
# std       0.448108  2.110307e+07  2.110307e+07     0.051604
# min      -6.703177 -1.809008e+08 -3.937875e+00    -0.028308
# 25%      -0.002342 -3.895075e-02  2.788341e-03     0.001431
# 50%       0.000949  9.120533e-04  1.226745e-01     0.028213
# 75%       0.011885  4.000710e-03  1.909992e-01     0.071664
# max       3.546317  9.377265e+00  1.809008e+08     0.244715

# %%
# ~25%
split_point=7131
train = merged_df.iloc[:split_point]        # Create upper data set
test = merged_df.iloc[split_point:]        # Create lower data set

# %%
train.shape
# Out:
# (7131, 4)

# %%
test.shape
# Out:
# (2378, 4)

# %%
# Visualize train data
plt.figure(figsize=(20,5))
fig, ax = plt.subplots()
lines = plt.plot(train.index, train.TAC_Reading)
plt.setp(lines, linewidth=1.0)
plt.xticks(rotation = 45)
plt.title('10s TAC_Reading train')
plt.xlabel('time')
plt.ylabel('TAC_Reading')
plt.legend(['Mean TAC_Reading'],loc = 'best')
plt.figure()
plt.show()
plt.figure(figsize=(20,5))
fig, ax = plt.subplots()
lines = plt.plot(test.index, test.TAC_Reading)
plt.setp(lines, linewidth=1.0)
plt.xticks(rotation = 45)
plt.title('10s TAC_Reading test')
plt.xlabel('time')
plt.ylabel('TAC_Reading')
plt.legend(['Mean TAC_Reading'],loc = 'best')
plt.show()

# %%
merged_df
# Out:
#                             x         y         z  TAC_Reading
# Time
# 2017-05-02 19:34:40 -0.012025 -0.002505 -0.005056     0.000000
# 2017-05-02 19:34:50  0.000126  0.000932 -0.003042     0.000000
# 2017-05-02 19:35:00  0.007597  0.001715 -0.000946     0.000000
# 2017-05-02 19:35:10  0.000067  0.000155 -0.003040     0.000000
# 2017-05-02 19:35:20 -0.000087 -0.000087 -0.001838     0.000000
# ...                       ...       ...       ...          ...
# 2017-05-03 22:03:30  0.025701  0.261930  0.174525    -0.002856
# 2017-05-03 22:03:40 -0.071388  0.209505  0.230314    -0.002856
# 2017-05-03 22:03:50  0.033098  0.301036  0.194274    -0.002856
# 2017-05-03 22:04:00  0.107928  0.235360  0.243888    -0.002856
# 2017-05-03 22:04:10 -0.057881  0.191652  0.172469    -0.002856
#
# [9509 rows x 4 columns]

# %%
merged_df=merged_df.sort_values(by='Time')

# %%
merged_df
# Out:
#                             x         y         z  TAC_Reading
# Time
# 2017-05-02 19:34:40 -0.012025 -0.002505 -0.005056     0.000000
# 2017-05-02 19:34:50  0.000126  0.000932 -0.003042     0.000000
# 2017-05-02 19:35:00  0.007597  0.001715 -0.000946     0.000000
# 2017-05-02 19:35:10  0.000067  0.000155 -0.003040     0.000000
# 2017-05-02 19:35:20 -0.000087 -0.000087 -0.001838     0.000000
# ...                       ...       ...       ...          ...
# 2017-05-03 22:03:30  0.025701  0.261930  0.174525    -0.002856
# 2017-05-03 22:03:40 -0.071388  0.209505  0.230314    -0.002856
# 2017-05-03 22:03:50  0.033098  0.301036  0.194274    -0.002856
# 2017-05-03 22:04:00  0.107928  0.235360  0.243888    -0.002856
# 2017-05-03 22:04:10 -0.057881  0.191652  0.172469    -0.002856
#
# [9509 rows x 4 columns]

# %%
import torch 
from torch import nn

# %%
X=merged_df.drop(columns='TAC_Reading', axis=1)
y=merged_df['TAC_Reading']

# %%
X= torch.from_numpy(np.asarray(X)).type(torch.float)
y= torch.from_numpy(np.asarray(y)).type(torch.float)

# %%
plt.plot(y)

# %%
# binary classification

# %%
merged_df
# Out:
#                             x         y         z  TAC_Reading
# Time
# 2017-05-02 19:34:40 -0.012025 -0.002505 -0.005056     0.000000
# 2017-05-02 19:34:50  0.000126  0.000932 -0.003042     0.000000
# 2017-05-02 19:35:00  0.007597  0.001715 -0.000946     0.000000
# 2017-05-02 19:35:10  0.000067  0.000155 -0.003040     0.000000
# 2017-05-02 19:35:20 -0.000087 -0.000087 -0.001838     0.000000
# ...                       ...       ...       ...          ...
# 2017-05-03 22:03:30  0.025701  0.261930  0.174525    -0.002856
# 2017-05-03 22:03:40 -0.071388  0.209505  0.230314    -0.002856
# 2017-05-03 22:03:50  0.033098  0.301036  0.194274    -0.002856
# 2017-05-03 22:04:00  0.107928  0.235360  0.243888    -0.002856
# 2017-05-03 22:04:10 -0.057881  0.191652  0.172469    -0.002856
#
# [9509 rows x 4 columns]

# %%
merged_df['TAC_Reading'] = np.where(merged_df['TAC_Reading'] < 0.08, 0, 1)
merged_df
# Out:
#                             x         y         z  TAC_Reading
# Time
# 2017-05-02 19:34:40 -0.012025 -0.002505 -0.005056            0
# 2017-05-02 19:34:50  0.000126  0.000932 -0.003042            0
# 2017-05-02 19:35:00  0.007597  0.001715 -0.000946            0
# 2017-05-02 19:35:10  0.000067  0.000155 -0.003040            0
# 2017-05-02 19:35:20 -0.000087 -0.000087 -0.001838            0
# ...                       ...       ...       ...          ...
# 2017-05-03 22:03:30  0.025701  0.261930  0.174525            0
# 2017-05-03 22:03:40 -0.071388  0.209505  0.230314            0
# 2017-05-03 22:03:50  0.033098  0.301036  0.194274            0
# 2017-05-03 22:04:00  0.107928  0.235360  0.243888            0
# 2017-05-03 22:04:10 -0.057881  0.191652  0.172469            0
#
# [9509 rows x 4 columns]

# %%
merged_df['TAC_Reading'].value_counts()
# Out:
# TAC_Reading
# 0    7490
# 1    2019
# Name: count, dtype: int64

# %%
import torch 
from torch import nn

# %%
X=merged_df.drop(columns=['TAC_Reading'], axis=1)
y=merged_df['TAC_Reading']

# %%
X= torch.from_numpy(np.asarray(X)).type(torch.float)
y= torch.from_numpy(np.asarray(y)).type(torch.float)

# %%
X.shape, y.shape
# Out:
# (torch.Size([9509, 3]), torch.Size([9509]))

# %%
#visualisations
plt.scatter(x=X[:, 1],y=X[:, 0], c=y)
plt.show()

# %%
#turning to train- test splits
train_split = int(0.75 *len(X))
X_train, y_train = X[:train_split], y[:train_split]
X_test, y_test = X[train_split:], y[train_split:]
len(X_train), len(X_test) , len(y_train) , len(y_test)
# Out:
# (7131, 2378, 7131, 2378)

# %%
X_test.shape
# Out:
# torch.Size([2378, 3])

# %%
y_test.shape
# Out:
# torch.Size([2378])

# %%
X_test.shape, y_train.shape, y_test.shape
# Out:
# (torch.Size([2378, 3]), torch.Size([7131]), torch.Size([2378]))

# %%
#builing a model
#subclas nn.Module
class DrunkModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.layer_1=nn.Linear(in_features=3,out_features=32)
        self.layer_2=nn.Linear(in_features=32,out_features=16)
        self.layer_3=nn.Linear(in_features=16,out_features=1)
        self.relu=nn.ReLU()
    
    def forward(self,x):
        return self.layer_3(self.relu(self.layer_2(self.relu(self.layer_1(x)))))
    
    
drunk_model=DrunkModel()
drunk_model
# Out:
# DrunkModel(
#   (layer_1): Linear(in_features=3, out_features=32, bias=True)
#   (layer_2): Linear(in_features=32, out_features=16, bias=True)
#   (layer_3): Linear(in_features=16, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %%
#accuracy function
#calc accuracy
def accuracy_fn(y_true,y_pred):
    correct=torch.eq(y_true,y_pred).sum().item()
    acc=(correct/len(y_pred)) * 100
    return acc

# %%
#view first 5 outputs of forward pass on test data
drunk_model.eval()
with torch.inference_mode():
    y_logits=drunk_model(X_test)[:5]
y_logits
# Out:
# tensor([[0.2716],
#         [0.2717],
#         [0.2712],
#         [0.2717],
#         [0.2715]])

# %%
len(y_logits)
# Out:
# 5

# %%
#use sigmoid activation funtion on our model logits to tun them into prediction probablities
y_pred_probs = torch.sigmoid(y_logits)
y_pred_probs
# Out:
# tensor([[0.5675],
#         [0.5675],
#         [0.5674],
#         [0.5675],
#         [0.5675]])

# %%
torch.round(y_pred_probs)
# Out:
# tensor([[1.],
#         [1.],
#         [1.],
#         [1.],
#         [1.]])

# %%
#find the predicted lables
y_preds = torch.round(y_pred_probs)

#in full
y_pred_labels=torch.round(torch.sigmoid(drunk_model(X_test)))[:5]

# check for equality
print(torch.eq(y_preds.squeeze(),y_pred_labels.squeeze()))

# Check the shapes of y_preds and y_pred_labels
print(y_preds.shape)
print(y_pred_labels.shape)
#get rid of extra dimension
y_preds.squeeze()
# Out:
# tensor([True, True, True, True, True])
# torch.Size([5, 1])
# torch.Size([5, 1])
# tensor([1., 1., 1., 1., 1.])

# %%
#loss function
loss_fn= nn.BCEWithLogitsLoss()
# #optimizer
# optimizer=torch.optim.SGD(drunk_model.parameters(),
#                           lr=0.1)
import torch.optim as optim

weight_decay = 0.001
optimizer = optim.Adam(drunk_model.parameters(), 
                       lr=0.001,
                       weight_decay=weight_decay )

# %%
len(y_logits), len(y_train)
# Out:
# (5, 7131)

# %%
#training loop
torch.manual_seed(42)

epochs=5000
for epoch in range(epochs):
    drunk_model.train()
    y_logits=drunk_model(X_train).squeeze(1)
    y_pred= torch.round(torch.sigmoid(y_logits))
    
    loss=loss_fn(y_logits,y_train)
    acc= accuracy_fn(y_true=y_train,y_pred=y_pred)
    
    optimizer.zero_grad()
    
    loss.backward()
    
    optimizer.step()
    
    drunk_model.eval()
    with torch.inference_mode():
        test_logits = drunk_model(X_test).squeeze(1)
        test_pred = torch.round(torch.sigmoid(test_logits))
        
        test_loss= loss_fn(test_logits,y_test)
        test_acc= accuracy_fn(y_true=y_test,y_pred=test_pred)
        
    if epoch%1000==0:
        print(f"Epoch: {epoch} | Train Loss: {loss: .5f},  Train Acc:{acc:.2f}% | Test loss: {test_loss:.5f}, Test acc: {test_acc:.2f}%")
# Out:
# Epoch: 0 | Train Loss:  609698.56250,  Train Acc:28.31% | Test loss: 0.83192, Test acc: 0.00%
# Epoch: 1000 | Train Loss:  9161.67090,  Train Acc:71.94% | Test loss: 0.26320, Test acc: 99.12%
# Epoch: 2000 | Train Loss:  15600.55762,  Train Acc:70.90% | Test loss: 0.23200, Test acc: 98.07%
# Epoch: 3000 | Train Loss:  1236.62402,  Train Acc:72.11% | Test loss: 0.22841, Test acc: 98.11%
# Epoch: 4000 | Train Loss:  1964.27344,  Train Acc:70.87% | Test loss: 0.22980, Test acc: 98.15%

# %% [markdown]
# # When weight decay in adam optimizer is used
# * Epoch: 0 | Train Loss:  0.48196,  Train Acc:72.77% | Test loss: 0.30115, Test acc: 94.32%
# * Epoch: 1000 | Train Loss:  0.51203,  Train Acc:71.80% | Test loss: 0.33218, Test acc: 99.24%
# * Epoch: 2000 | Train Loss:  0.50944,  Train Acc:71.83% | Test loss: 0.38359, Test acc: 99.12%
# * Epoch: 3000 | Train Loss:  0.50996,  Train Acc:71.93% | Test loss: 0.53256, Test acc: 98.99%
# * Epoch: 4000 | Train Loss:  0.50942,  Train Acc:71.95% | Test loss: 0.55625, Test acc: 99.33%

# %% [markdown]
# # When weight decay in adam optimizer is not used
# * Epoch: 0 | Train Loss:  106349.85156,  Train Acc:28.31% | Test loss: 0.56545, Test acc: 100.00%
# * Epoch: 1000 | Train Loss:  0.49138,  Train Acc:72.77% | Test loss: 0.20925, Test acc: 93.61%
# * Epoch: 2000 | Train Loss:  0.48786,  Train Acc:72.81% | Test loss: 0.30038, Test acc: 93.31%
# * Epoch: 3000 | Train Loss:  0.48509,  Train Acc:73.06% | Test loss: 0.36906, Test acc: 93.48%
# * Epoch: 4000 | Train Loss:  0.48303,  Train Acc:73.06% | Test loss: 0.42814, Test acc: 92.22%

# %% [markdown]
# * Epoch: 0 | Train Loss:  665819.87500,  Train Acc:71.69% | Test loss: 0.33915, Test acc: 99.96%
# * Epoch: 1000 | Train Loss:  0.48767,  Train Acc:72.47% | Test loss: 0.16634, Test acc: 97.22%
# * Epoch: 2000 | Train Loss:  0.48831,  Train Acc:72.47% | Test loss: 0.18563, Test acc: 97.27%
# *Epoch: 3000 | Train Loss:  0.48624,  Train Acc:72.50% | Test loss: 0.20153, Test acc: 97.18%
# *Epoch: 4000 | Train Loss:  0.48535,  Train Acc:72.57% | Test loss: 0.21068, Test acc: 97.18%

# %% [markdown]
# # When sdg is used (over fitting)
# * Epoch: 0 | Train Loss:  106349.85156,  Train Acc:28.31% | Test loss: 0.00000, Test acc: 100.00%
# * Epoch: 1000 | Train Loss:  0.59589,  Train Acc:71.69% | Test loss: 0.33286, Test acc: 100.00%
# * Epoch: 2000 | Train Loss:  0.59589,  Train Acc:71.69% | Test loss: 0.33286, Test acc: 100.00%
# * Epoch: 3000 | Train Loss:  0.59589,  Train Acc:71.69% | Test loss: 0.33286, Test acc: 100.00%
# * Epoch: 4000 | Train Loss:  0.59589,  Train Acc:71.69% | Test loss: 0.33286, Test acc: 100.00%

# %% [markdown]
# # When adam is used with lr =0.001
# * Epoch: 0 | Train Loss:  106349.85156,  Train Acc:28.31% | Test loss: 0.83485, Test acc: 0.08%
# * Epoch: 1000 | Train Loss:  14394.20215,  Train Acc:72.01% | Test loss: 0.22119, Test acc: 96.17%
# * Epoch: 2000 | Train Loss:  3818.80811,  Train Acc:71.01% | Test loss: 0.17217, Test acc: 96.17%
# * Epoch: 3000 | Train Loss:  4564.89062,  Train Acc:70.93% | Test loss: 0.15873, Test acc: 96.38%
# * Epoch: 4000 | Train Loss:  2008.01123,  Train Acc:70.61% | Test loss: 0.15119, Test acc: 96.26%

# %% [markdown]
# # When adam is used with lr=0.001 and weight decay=0.001
# * Epoch: 0 | Train Loss:  106349.85156,  Train Acc:28.31% | Test loss: 0.83486, Test acc: 0.08%
# * Epoch: 1000 | Train Loss:  6829.43311,  Train Acc:71.76% | Test loss: 0.25432, Test acc: 99.45%
# * Epoch: 2000 | Train Loss:  2218.27002,  Train Acc:71.87% | Test loss: 0.22586, Test acc: 99.29%
# * Epoch: 3000 | Train Loss:  5884.79199,  Train Acc:72.11% | Test loss: 0.21660, Test acc: 98.65%
# *Epoch: 4000 | Train Loss:  1541.46472,  Train Acc:72.08% | Test loss: 0.21795, Test acc: 97.86%

# %% [markdown]
# * Epoch: 0 | Train Loss:  609698.56250,  Train Acc:28.31% | Test loss: 0.83192, Test acc: 0.00%
# * Epoch: 1000 | Train Loss:  9161.67090,  Train Acc:71.94% | Test loss: 0.26320, Test acc: 99.12%
# *Epoch: 2000 | Train Loss:  15600.55762,  Train Acc:70.90% | Test loss: 0.23200, Test acc: 98.07%
# *Epoch: 3000 | Train Loss:  1236.62402,  Train Acc:72.11% | Test loss: 0.22841, Test acc: 98.11%
# *Epoch: 4000 | Train Loss:  1964.27344,  Train Acc:70.87% | Test loss: 0.22980, Test acc: 98.15%
